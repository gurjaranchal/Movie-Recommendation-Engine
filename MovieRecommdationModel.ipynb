# %%
import pandas as pd

# %%
df = pd.read_csv(r'movie_metadata.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df[['genres', 'movie_title', 'movie_imdb_link','imdb_score']]
# Out:
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 5038                     Comedy|Drama
# 5039     Crime|Drama|Mystery|Thriller
# 5040            Drama|Horror|Thriller
# 5041             Comedy|Drama|Romance
# 5042                      Documentary
#
#                                             movie_title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# ...

# %%
selected_data=df[['genres', 'movie_title', 'movie_imdb_link','imdb_score']]

# %%
selected_data
# Out:
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 5038                     Comedy|Drama
# 5039     Crime|Drama|Mystery|Thriller
# 5040            Drama|Horror|Thriller
# 5041             Comedy|Drama|Romance
# 5042                      Documentary
#
#                                             movie_title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# ...

# %%
genres_list=[selected_data .loc[i]['genres'].split('|') for i in selected_data .index]

# %%
genreslist = sorted(list(set([item for sublist in genres_list for item in sublist])))

# %%
genreslist
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']

# %%
genreslist[0]
# Out:
# 'Action'

# %%
print(genreslist)
# Out:
# ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Thriller', 'War', 'Western']

# %%
print(len(genreslist))
# Out:
# 26

# %%
title=[]
for i in selected_data.index:
    title.append(selected_data.loc[i]['movie_title'].strip(),i,selected_data.loc[i]['movie_imdb_link'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 title=[]
#       2 for i in selected_data.index:
# ----> 3     title.append(selected_data.loc[i]['movie_title'].strip(),i,selected_data.loc[i]['movie_imdb_link'])
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
for i in selected_data.index:
    title.append((selected_data.loc[i]['movie_title'].strip(),i,selected_data.loc[i]['movie_imdb_link'].strip())
# Out:
#   Input In [15]
#     title.append((selected_data.loc[i]['movie_title'].strip(),i,selected_data.loc[i]['movie_imdb_link'].strip())
#                                                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
title=[]

# %%
for i in selected_data.index:
    title.append((selected_data.loc[i]['movie_title'].strip(),i,selected_data.loc[i]['movie_imdb_link'].strip()))

# %%
import json

# %%
movie_info=[]
for i in selected_data.index:
    data=[1 if genre in selected_data.loc[i]['genres'].split('|') else 0 for genre in genreslist]
    data.append(selected_data.loc[i]['imdb_score'])
    movie_info.append(data)

# %%
data1 = r'title.json'

# %%
with open(data1,'w+',encoding='utf-8') as final:
    json.dump(title,final)

# %%
data2=r'data.json'

# %%
with open(data2,'w+',encoding='utf-8') as final:
    json.dump(movie_info,final)

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
new_data=df[['movie_title','genres','director_name','movie_imdb_link','imdb_score']]

# %%
new_data.head()
# Out:
#                                          movie_title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                             genres      director_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron
# 1         Action|Adventure|Fantasy     Gore Verbinski
# 2        Action|Adventure|Thriller         Sam Mendes
# 3                  Action|Thriller  Christopher Nolan
# 4                      Documentary        Doug Walker
#
#                                      movie_imdb_link  imdb_score
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...         7.9
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...         7.1
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...         6.8
# ...

# %%
import pickle

# %%
pickle.dump(new_data.to_dict(),open('info.pkl','wb'))
